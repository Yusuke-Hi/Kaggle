# %% [markdown]
# # Only Tablar Model

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import pandas.api.types
import matplotlib.pyplot as plt

from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import GroupKFold, StratifiedGroupKFold
from sklearn.ensemble import VotingClassifier

import catboost as cb
import lightgbm as lgb
from tqdm.auto import tqdm
import gc

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Feature Engineering

# %%
df_train = pd.read_csv("/kaggle/input/isic-2024-challenge/train-metadata.csv")
df_test = pd.read_csv("/kaggle/input/isic-2024-challenge/test-metadata.csv")

def feature_engineering(df):
    # New features to try...
    df["lesion_size_ratio"] = df["tbp_lv_minorAxisMM"] / df["clin_size_long_diam_mm"]
    df["lesion_shape_index"] = df["tbp_lv_areaMM2"] / (df["tbp_lv_perimeterMM"] ** 2)
    df["hue_contrast"] = (df["tbp_lv_H"] - df["tbp_lv_Hext"]).abs()
    df["luminance_contrast"] = (df["tbp_lv_L"] - df["tbp_lv_Lext"]).abs()
    df["lesion_color_difference"] = np.sqrt(df["tbp_lv_deltaA"] ** 2 + df["tbp_lv_deltaB"] ** 2 + df["tbp_lv_deltaL"] ** 2)
    df["border_complexity"] = df["tbp_lv_norm_border"] + df["tbp_lv_symm_2axis"]
    df["color_uniformity"] = df["tbp_lv_color_std_mean"] / df["tbp_lv_radial_color_std_max"]
    df["3d_position_distance"] = np.sqrt(df["tbp_lv_x"] ** 2 + df["tbp_lv_y"] ** 2 + df["tbp_lv_z"] ** 2) 
    df["perimeter_to_area_ratio"] = df["tbp_lv_perimeterMM"] / df["tbp_lv_areaMM2"]
    df["lesion_visibility_score"] = df["tbp_lv_deltaLBnorm"] + df["tbp_lv_norm_color"]
    df["combined_anatomical_site"] = df["anatom_site_general"] + "_" + df["tbp_lv_location"]
    df["symmetry_border_consistency"] = df["tbp_lv_symm_2axis"] * df["tbp_lv_norm_border"]
    df["color_consistency"] = df["tbp_lv_stdL"] / df["tbp_lv_Lext"]
    
    df["size_age_interaction"] = df["clin_size_long_diam_mm"] * df["age_approx"]
    df["hue_color_std_interaction"] = df["tbp_lv_H"] * df["tbp_lv_color_std_mean"]
    df["lesion_severity_index"] = (df["tbp_lv_norm_border"] + df["tbp_lv_norm_color"] + df["tbp_lv_eccentricity"]) / 3
    df["shape_complexity_index"] = df["border_complexity"] + df["lesion_shape_index"]
    df["color_contrast_index"] = df["tbp_lv_deltaA"] + df["tbp_lv_deltaB"] + df["tbp_lv_deltaL"] + df["tbp_lv_deltaLBnorm"]
    df["log_lesion_area"] = np.log(df["tbp_lv_areaMM2"] + 1)
    df["normalized_lesion_size"] = df["clin_size_long_diam_mm"] / df["age_approx"]
    df["mean_hue_difference"] = (df["tbp_lv_H"] + df["tbp_lv_Hext"]) / 2
    df["std_dev_contrast"] = np.sqrt((df["tbp_lv_deltaA"] ** 2 + df["tbp_lv_deltaB"] ** 2 + df["tbp_lv_deltaL"] ** 2) / 3)
    df["color_shape_composite_index"] = (df["tbp_lv_color_std_mean"] + df["tbp_lv_area_perim_ratio"] + df["tbp_lv_symm_2axis"]) / 3
    df["3d_lesion_orientation"] = np.arctan2(df_train["tbp_lv_y"], df_train["tbp_lv_x"])
    df["overall_color_difference"] = (df["tbp_lv_deltaA"] + df["tbp_lv_deltaB"] + df["tbp_lv_deltaL"]) / 3
    df["symmetry_perimeter_interaction"] = df["tbp_lv_symm_2axis"] * df["tbp_lv_perimeterMM"]
    df["comprehensive_lesion_index"] = (df["tbp_lv_area_perim_ratio"] + df["tbp_lv_eccentricity"] + df["tbp_lv_norm_color"] + df["tbp_lv_symm_2axis"]) / 4

    # Taken from: https://www.kaggle.com/code/dschettler8845/isic-detect-skin-cancer-let-s-learn-together
    df["color_variance_ratio"] = df["tbp_lv_color_std_mean"] / df["tbp_lv_stdLExt"]
    df["border_color_interaction"] = df["tbp_lv_norm_border"] * df["tbp_lv_norm_color"]
    df["size_color_contrast_ratio"] = df["clin_size_long_diam_mm"] / df["tbp_lv_deltaLBnorm"]
    df["age_normalized_nevi_confidence"] = df["tbp_lv_nevi_confidence"] / df["age_approx"]
    df["color_asymmetry_index"] = df["tbp_lv_radial_color_std_max"] * df["tbp_lv_symm_2axis"]
    df["3d_volume_approximation"] = df["tbp_lv_areaMM2"] * np.sqrt(df["tbp_lv_x"]**2 + df["tbp_lv_y"]**2 + df["tbp_lv_z"]**2)
    df["color_range"] = (df["tbp_lv_L"] - df["tbp_lv_Lext"]).abs() + (df["tbp_lv_A"] - df["tbp_lv_Aext"]).abs() + (df["tbp_lv_B"] - df["tbp_lv_Bext"]).abs()
    df["shape_color_consistency"] = df["tbp_lv_eccentricity"] * df["tbp_lv_color_std_mean"]
    df["border_length_ratio"] = df["tbp_lv_perimeterMM"] / (2 * np.pi * np.sqrt(df["tbp_lv_areaMM2"] / np.pi))
    df["age_size_symmetry_index"] = df["age_approx"] * df["clin_size_long_diam_mm"] * df["tbp_lv_symm_2axis"]
    # Until here.
    
    new_num_cols = [
        "lesion_size_ratio", "lesion_shape_index", "hue_contrast",
        "luminance_contrast", "lesion_color_difference", "border_complexity",
        "color_uniformity", "3d_position_distance", "perimeter_to_area_ratio",
        "lesion_visibility_score", "symmetry_border_consistency", "color_consistency",

        "size_age_interaction", "hue_color_std_interaction", "lesion_severity_index", 
        "shape_complexity_index", "color_contrast_index", "log_lesion_area",
        "normalized_lesion_size", "mean_hue_difference", "std_dev_contrast",
        "color_shape_composite_index", "3d_lesion_orientation", "overall_color_difference",
        "symmetry_perimeter_interaction", "comprehensive_lesion_index",
        
        "color_variance_ratio", "border_color_interaction", "size_color_contrast_ratio",
        "age_normalized_nevi_confidence", "color_asymmetry_index", "3d_volume_approximation",
        "color_range", "shape_color_consistency", "border_length_ratio", "age_size_symmetry_index",
    ]
    new_cat_cols = ["combined_anatomical_site"]
    return df, new_num_cols, new_cat_cols

num_cols = [
    'age_approx', 'clin_size_long_diam_mm', 'tbp_lv_A', 'tbp_lv_Aext', 'tbp_lv_B', 'tbp_lv_Bext', 
    'tbp_lv_C', 'tbp_lv_Cext', 'tbp_lv_H', 'tbp_lv_Hext', 'tbp_lv_L', 
    'tbp_lv_Lext', 'tbp_lv_areaMM2', 'tbp_lv_area_perim_ratio', 'tbp_lv_color_std_mean', 
    'tbp_lv_deltaA', 'tbp_lv_deltaB', 'tbp_lv_deltaL', 'tbp_lv_deltaLB',
    'tbp_lv_deltaLBnorm', 'tbp_lv_eccentricity', 'tbp_lv_minorAxisMM',
    'tbp_lv_nevi_confidence', 'tbp_lv_norm_border', 'tbp_lv_norm_color',
    'tbp_lv_perimeterMM', 'tbp_lv_radial_color_std_max', 'tbp_lv_stdL',
    'tbp_lv_stdLExt', 'tbp_lv_symm_2axis', 'tbp_lv_symm_2axis_angle',
    'tbp_lv_x', 'tbp_lv_y', 'tbp_lv_z',
]
df_train[num_cols] = df_train[num_cols].fillna(df_train[num_cols].median())
df_train, new_num_cols, new_cat_cols = feature_engineering(df_train.copy())
df_test, _, _ = feature_engineering(df_test.copy())
num_cols += new_num_cols
# anatom_site_general
cat_cols = ["sex", "tbp_tile_type", "tbp_lv_location", "tbp_lv_location_simple"] + new_cat_cols
train_cols = num_cols + cat_cols

gc.collect()

category_encoder = OrdinalEncoder(
    categories='auto',
    dtype=int,
    handle_unknown='use_encoded_value',
    unknown_value=-2,
    encoded_missing_value=-1,
)

X_cat = category_encoder.fit_transform(df_train[cat_cols])
for c, cat_col in enumerate(cat_cols):
    df_train[cat_col] = X_cat[:, c]

# %%
gc.collect()
# Out:
# 0

# %%
df_train.shape, df_test.shape
# Out:
# ((401059, 92), (3, 81))

# %%
df_train.head(3)
# Out:
#         isic_id  target  patient_id  age_approx  sex anatom_site_general  \
# 0  ISIC_0015670       0  IP_1235828        60.0    1     lower extremity
# 1  ISIC_0015845       0  IP_8170065        60.0    1           head/neck
# 2  ISIC_0015864       0  IP_6724798        60.0    1     posterior torso
#
#    clin_size_long_diam_mm          image_type  tbp_tile_type   tbp_lv_A  ...  \
# 0                    3.04  TBP tile: close-up              1  20.244422  ...
# 1                    1.10  TBP tile: close-up              1  31.712570  ...
# 2                    3.40  TBP tile: close-up              0  22.575830  ...
#
#    color_variance_ratio  border_color_interaction  size_color_contrast_ratio  \
# 0                   0.0                       0.0                   0.525560
# 1                   0.0                       0.0                   0.220563
# 2                   0.0                       0.0                   0.540510
#
#    age_normalized_nevi_confidence  color_asymmetry_index  \
# 0                    4.380987e-05                    0.0
# 1                    2.223838e-09                    0.0
# 2                    4.931962e-06                    0.0
#
#    3d_volume_approximation  color_range  shape_color_consistency  \
# 0              2022.449088    14.608375                      0.0
# 1              1449.793110    14.630380                      0.0
# 2              4882.849628    17.642050                      0.0
#
#    border_length_ratio  age_size_symmetry_index
# 0             1.478676               107.702857
# 1             0.986739                18.857144
# 2             1.387282                73.828579
#
# [3 rows x 92 columns]

# %% [markdown]
# # CV Setup

# %%
N_SPLITS = 5
sgkf = StratifiedGroupKFold(n_splits=N_SPLITS)

df_train["fold"] = -1
for idx, (train_idx, val_idx) in enumerate(sgkf.split(df_train, df_train["target"], groups=df_train["patient_id"])):
    df_train.loc[val_idx, "fold"] = idx

# %% [markdown]
# # Competition Metric

# %%
def comp_score(solution: pd.DataFrame, submission: pd.DataFrame, row_id_column_name: str, min_tpr: float=0.80):
    v_gt = abs(np.asarray(solution.values)-1)
    v_pred = np.array([1.0 - x for x in submission.values])
    max_fpr = abs(1-min_tpr)
    partial_auc_scaled = roc_auc_score(v_gt, v_pred, max_fpr=max_fpr)
    # change scale from [0.5, 1.0] to [0.5 * max_fpr**2, max_fpr]
    # https://math.stackexchange.com/questions/914823/shift-numbers-into-a-different-range
    partial_auc = 0.5 * max_fpr**2 + (max_fpr - 0.5 * max_fpr**2) / (1.0 - 0.5) * (partial_auc_scaled - 0.5)
    return partial_auc

# %% [markdown]
# # LGBM Model

# %%
# def objective(trial):
#     param = {
#         "objective": "binary",
#         # "metric": "custom",
#         "verbosity": -1,
#         "boosting_type": trial.suggest_categorical("boosting_type", ["gbdt", "dart"]),
#         "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
#         "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
#         "num_leaves": trial.suggest_int("num_leaves", 2, 256),
#         "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
#         "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
#         "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
#         "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
#         "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
#         "max_depth": trial.suggest_int("max_depth", -1, 50),
#         "min_split_gain": trial.suggest_float("min_split_gain", 0, 1),
#         "subsample": trial.suggest_float("subsample", 0.4, 1.0),
#         "device": "gpu"
#     }
#     scores = []
#     for fold in range(N_SPLITS):
#         _df_train = df_train[df_train["fold"] != fold].reset_index(drop=True)
#         _df_valid = df_train[df_train["fold"] == fold].reset_index(drop=True)
#         dtrain = lgb.Dataset(_df_train[train_cols], label=_df_train["target"])
#         #dvalid = lgb.Dataset(_df_valid[train_cols], label=_df_valid["target"])
#         gbm = lgb.train(param, dtrain)
#         preds = gbm.predict(_df_valid[train_cols])
#         score = comp_score(_df_valid[["target"]], pd.DataFrame(preds, columns=["prediction"]), "")
#         scores.append(score)
#     return np.mean(scores)

# %%
# import optuna
# study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=100)

# print("Number of finished trials: {}".format(len(study.trials)))

# print("Best trial:")
# trial = study.best_trial

# print("  Value: {}".format(trial.value))

# print("  Params: ")
# for key, value in trial.params.items():
#     print("    {}: {}".format(key, value))
# Out:
# [I 2024-07-25 23:03:23,401] A new study created in memory with name: no-name-744d029e-f22c-4af1-9b9b-83d37eda04ee
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# [I 2024-07-25 23:04:25,665] Trial 0 finished with value: 0.03370373095185565 and parameters: {'boosting_type': 'dart', 'lambda_l1': 1.5983663025348456, 'lambda_l2': 4.509431474568373e-05, 'num_leaves': 233, 'feature_fraction': 0.464841396787288, 'bagging_fraction': 0.9458281855969659, 'bagging_freq': 1, 'min_child_samples': 10, 'learning_rate': 0.05532596987897499, 'max_depth': 49, 'min_split_gain': 0.3318675763398994, 'subsample': 0.41871107540397196}. Best is trial 0 with value: 0.03370373095185565.
# [I 2024-07-25 23:04:56,917] Trial 1 finished with value: 0.020139965340067775 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.006468080674734237, 'lambda_l2': 1.5447947969991074e-07, 'num_leaves': 57, 'feature_fraction': 0.5396864701863718, 'bagging_fraction': 0.7643016807204788, 'bagging_freq': 6, 'min_child_samples': 24, 'learning_rate': 0.2298516764825232, 'max_depth': 35, 'min_split_gain': 0.6522234282755339, 'subsample': 0.41828823865221365}. Best is trial 0 with value: 0.03370373095185565.
# [I 2024-07-25 23:05:44,755] Trial 2 finished with value: 0.14781723450394585 and parameters: {'boosting_type': 'dart', 'lambda_l1': 6.817638563494476, 'lambda_l2': 1.5819669414585258, 'num_leaves': 58, 'feature_fraction': 0.8896098384187499, 'bagging_fraction': 0.8040773239294277, 'bagging_freq': 1, 'min_child_samples': 75, 'learning_rate': 0.2840239360910166, 'max_depth': 22, 'min_split_gain': 0.041097676232498825, 'subsample': 0.674427820611942}. Best is trial 2 with value: 0.14781723450394585.
# [I 2024-07-25 23:06:52,937] Trial 3 finished with value: 0.11621974047972794 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.002780404395075131, 'lambda_l2': 6.263309344185562e-08, 'num_leaves': 137, 'feature_fraction': 0.660441884341144, 'bagging_fraction': 0.41188750161887877, 'bagging_freq': 6, 'min_child_samples': 27, 'learning_rate': 0.021751575689718222, 'max_depth': 21, 'min_split_gain': 0.1277156084250023, 'subsample': 0.6580117344246019}. Best is trial 2 with value: 0.14781723450394585.
# [I 2024-07-25 23:07:21,516] Trial 4 finished with value: 0.020041721454738263 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.045639629966026087, 'lambda_l2': 1.0753673590239605e-08, 'num_leaves': 59, 'feature_fraction': 0.7098155524872204, 'bagging_fraction': 0.9519562721687823, 'bagging_freq': 3, 'min_child_samples': 26, 'learning_rate': 0.29189124480510187, 'max_depth': 33, 'min_split_gain': 0.7028976114286496, 'subsample': 0.4994300269363493}. Best is trial 2 with value: 0.14781723450394585.
# [I 2024-07-25 23:07:54,934] Trial 5 finished with value: 0.012398276255610909 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.3552202208700965e-08, 'lambda_l2': 0.22590939733904167, 'num_leaves': 94, 'feature_fraction': 0.9896209874884658, 'bagging_fraction': 0.4658446590680301, 'bagging_freq': 4, 'min_child_samples': 52, 'learning_rate': 0.28618453118752196, 'max_depth': 50, 'min_split_gain': 0.5872093775233769, 'subsample': 0.6524547486635004}. Best is trial 2 with value: 0.14781723450394585.
# [I 2024-07-25 23:08:25,175] Trial 6 finished with value: 0.15239514735445106 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0062444192568332085, 'lambda_l2': 0.2688182403482201, 'num_leaves': 21, 'feature_fraction': 0.4546118443972494, 'bagging_fraction': 0.7841017289445359, 'bagging_freq': 3, 'min_child_samples': 18, 'learning_rate': 0.039218040063095205, 'max_depth': 11, 'min_split_gain': 0.29779904037478633, 'subsample': 0.7398390626588844}. Best is trial 6 with value: 0.15239514735445106.
# [I 2024-07-25 23:09:00,436] Trial 7 finished with value: 0.15326330699064256 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 4.070542054887062e-05, 'lambda_l2': 0.8450043879270582, 'num_leaves': 171, 'feature_fraction': 0.5909593172965053, 'bagging_fraction': 0.4544945573577657, 'bagging_freq': 3, 'min_child_samples': 14, 'learning_rate': 0.06661061085398803, 'max_depth': 19, 'min_split_gain': 0.4867259300917409, 'subsample': 0.7604241192462968}. Best is trial 7 with value: 0.15326330699064256.
# [I 2024-07-25 23:10:02,331] Trial 8 finished with value: 0.12411758014110967 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.0009473113231207858, 'lambda_l2': 0.007031272768989807, 'num_leaves': 253, 'feature_fraction': 0.9466053946945342, 'bagging_fraction': 0.5132609713738477, 'bagging_freq': 3, 'min_child_samples': 36, 'learning_rate': 0.054413355428948554, 'max_depth': 9, 'min_split_gain': 0.5525503048586917, 'subsample': 0.42929130254199627}. Best is trial 7 with value: 0.15326330699064256.
# [I 2024-07-25 23:11:03,311] Trial 9 finished with value: 0.0794851734088909 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.32535462875903554, 'lambda_l2': 0.0007893301870252853, 'num_leaves': 112, 'feature_fraction': 0.7890901618904542, 'bagging_fraction': 0.8157563300011186, 'bagging_freq': 7, 'min_child_samples': 21, 'learning_rate': 0.03778717429683521, 'max_depth': 30, 'min_split_gain': 0.8672972278864248, 'subsample': 0.4430250046031952}. Best is trial 7 with value: 0.15326330699064256.
# [I 2024-07-25 23:11:32,625] Trial 10 finished with value: 0.15389644443524259 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 4.498699022007504e-06, 'lambda_l2': 9.82346862646195, 'num_leaves': 185, 'feature_fraction': 0.5999453671871335, 'bagging_fraction': 0.5970026703576433, 'bagging_freq': 5, 'min_child_samples': 100, 'learning_rate': 0.1234945763512815, 'max_depth': -1, 'min_split_gain': 0.9862965974863772, 'subsample': 0.9990420987034336}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:11:53,666] Trial 11 finished with value: 0.14748294866530703 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 4.464879504264937e-06, 'lambda_l2': 7.891132413046443, 'num_leaves': 173, 'feature_fraction': 0.6019428875127611, 'bagging_fraction': 0.5940873797255973, 'bagging_freq': 5, 'min_child_samples': 99, 'learning_rate': 0.11485793744548901, 'max_depth': 1, 'min_split_gain': 0.9688379589640543, 'subsample': 0.9401422732474731}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:12:27,192] Trial 12 finished with value: 0.10059914913350183 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 9.572622780485339e-06, 'lambda_l2': 0.03594067560728906, 'num_leaves': 190, 'feature_fraction': 0.5634624272983758, 'bagging_fraction': 0.5966388534374008, 'bagging_freq': 4, 'min_child_samples': 99, 'learning_rate': 0.12150450355708844, 'max_depth': -1, 'min_split_gain': 0.38699106705256914, 'subsample': 0.9980313834049584}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:13:02,988] Trial 13 finished with value: 0.15356360702900182 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.1859661059628049e-05, 'lambda_l2': 6.113446198240329, 'num_leaves': 194, 'feature_fraction': 0.7450095908968465, 'bagging_fraction': 0.6014992605113787, 'bagging_freq': 2, 'min_child_samples': 70, 'learning_rate': 0.11783805972892661, 'max_depth': 13, 'min_split_gain': 0.7933630100568747, 'subsample': 0.8346995616038273}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:13:40,070] Trial 14 finished with value: 0.05834664397671689 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.6827973225511621e-07, 'lambda_l2': 3.594676489981951e-05, 'num_leaves': 201, 'feature_fraction': 0.7854152829066628, 'bagging_fraction': 0.6306073847600342, 'bagging_freq': 2, 'min_child_samples': 77, 'learning_rate': 0.13146803381777578, 'max_depth': 9, 'min_split_gain': 0.8149505182790377, 'subsample': 0.8655511510509178}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:14:10,321] Trial 15 finished with value: 0.15094213003901633 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 5.41598200125537e-07, 'lambda_l2': 6.422362003079276, 'num_leaves': 143, 'feature_fraction': 0.7526892272391482, 'bagging_fraction': 0.7005674267561574, 'bagging_freq': 5, 'min_child_samples': 81, 'learning_rate': 0.15969467903026638, 'max_depth': 14, 'min_split_gain': 0.983727449313444, 'subsample': 0.8443155817813798}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:14:38,446] Trial 16 finished with value: 0.15188395761635204 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 6.501321553339664e-05, 'lambda_l2': 0.012155554566336125, 'num_leaves': 222, 'feature_fraction': 0.661432613257201, 'bagging_fraction': 0.5424519482423675, 'bagging_freq': 2, 'min_child_samples': 62, 'learning_rate': 0.012105946565975238, 'max_depth': 4, 'min_split_gain': 0.8180127309524818, 'subsample': 0.8702256723711967}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:15:06,641] Trial 17 finished with value: 0.12134219687512875 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 3.959688150180552e-07, 'lambda_l2': 2.593855445992148e-06, 'num_leaves': 165, 'feature_fraction': 0.8487297062388863, 'bagging_fraction': 0.6602596680308741, 'bagging_freq': 5, 'min_child_samples': 87, 'learning_rate': 0.08372618001925267, 'max_depth': 4, 'min_split_gain': 0.7093168609873084, 'subsample': 0.9678050755801688}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:15:41,241] Trial 18 finished with value: 0.023339601311109643 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0001546932916201286, 'lambda_l2': 0.06885705456054399, 'num_leaves': 208, 'feature_fraction': 0.5179073133959241, 'bagging_fraction': 0.7044441797602401, 'bagging_freq': 2, 'min_child_samples': 60, 'learning_rate': 0.16674085938326622, 'max_depth': 15, 'min_split_gain': 0.9203038417226964, 'subsample': 0.7971277738619589}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:16:16,289] Trial 19 finished with value: 0.07882031686571914 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 4.17737958980356e-06, 'lambda_l2': 0.0021686670633941393, 'num_leaves': 251, 'feature_fraction': 0.40705479889453766, 'bagging_fraction': 0.5418246241347081, 'bagging_freq': 4, 'min_child_samples': 50, 'learning_rate': 0.10815638356328267, 'max_depth': 26, 'min_split_gain': 0.7599592041723591, 'subsample': 0.9107338986760012}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:16:45,414] Trial 20 finished with value: 0.10074380608330138 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.4816298036942555e-08, 'lambda_l2': 0.00015278927400355454, 'num_leaves': 154, 'feature_fraction': 0.6877670141338367, 'bagging_fraction': 0.8997497049271257, 'bagging_freq': 7, 'min_child_samples': 89, 'learning_rate': 0.08536180075378139, 'max_depth': 6, 'min_split_gain': 0.8846834546825906, 'subsample': 0.5860296681419646}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:17:19,734] Trial 21 finished with value: 0.14971674475615537 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 2.8806612756138834e-05, 'lambda_l2': 1.1118335807380495, 'num_leaves': 184, 'feature_fraction': 0.6073523489788882, 'bagging_fraction': 0.4233607181411718, 'bagging_freq': 3, 'min_child_samples': 67, 'learning_rate': 0.0722838508925946, 'max_depth': 17, 'min_split_gain': 0.44848050934867734, 'subsample': 0.7870082239713039}. Best is trial 10 with value: 0.15389644443524259.
# [I 2024-07-25 23:17:57,222] Trial 22 finished with value: 0.1543499909758462 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.00038749445855481906, 'lambda_l2': 1.0603162458615119, 'num_leaves': 120, 'feature_fraction': 0.616522114292694, 'bagging_fraction': 0.49397726091943295, 'bagging_freq': 2, 'min_child_samples': 39, 'learning_rate': 0.05750179462007603, 'max_depth': 39, 'min_split_gain': 0.4868866213707905, 'subsample': 0.7427972788423558}. Best is trial 22 with value: 0.1543499909758462.
# [I 2024-07-25 23:18:27,751] Trial 23 finished with value: 0.15402784766810823 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0005455234210485198, 'lambda_l2': 8.16691393978921, 'num_leaves': 116, 'feature_fraction': 0.7235214106904606, 'bagging_fraction': 0.5014682875283233, 'bagging_freq': 1, 'min_child_samples': 41, 'learning_rate': 0.03508550961346211, 'max_depth': 42, 'min_split_gain': 0.22917412779366464, 'subsample': 0.5851594899656836}. Best is trial 22 with value: 0.1543499909758462.
# [I 2024-07-25 23:19:01,539] Trial 24 finished with value: 0.15402428392840775 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0006564494523365636, 'lambda_l2': 0.40988523069558125, 'num_leaves': 114, 'feature_fraction': 0.6708674639112686, 'bagging_fraction': 0.5051966207779646, 'bagging_freq': 1, 'min_child_samples': 41, 'learning_rate': 0.02702263597388039, 'max_depth': 42, 'min_split_gain': 0.18300236253935376, 'subsample': 0.5833939642229797}. Best is trial 22 with value: 0.1543499909758462.
# [I 2024-07-25 23:19:50,421] Trial 25 finished with value: 0.15022580276015168 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.00044487790608738767, 'lambda_l2': 0.24227955272479143, 'num_leaves': 112, 'feature_fraction': 0.6395407930404202, 'bagging_fraction': 0.49761917081922713, 'bagging_freq': 1, 'min_child_samples': 40, 'learning_rate': 0.024730375826442302, 'max_depth': 43, 'min_split_gain': 0.22683138408323777, 'subsample': 0.565266296067289}. Best is trial 22 with value: 0.1543499909758462.
# [I 2024-07-25 23:20:23,155] Trial 26 finished with value: 0.15450790537980455 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.11838582500643993, 'lambda_l2': 0.03620457723169562, 'num_leaves': 88, 'feature_fraction': 0.8235992609021421, 'bagging_fraction': 0.5398794794743644, 'bagging_freq': 1, 'min_child_samples': 41, 'learning_rate': 0.024460805386542942, 'max_depth': 41, 'min_split_gain': 0.18638641890113405, 'subsample': 0.6027845693637915}. Best is trial 26 with value: 0.15450790537980455.
# [I 2024-07-25 23:21:13,718] Trial 27 finished with value: 0.14616498845687603 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.054692444876141943, 'lambda_l2': 0.05289370662013843, 'num_leaves': 83, 'feature_fraction': 0.8520031762673593, 'bagging_fraction': 0.5478429796669128, 'bagging_freq': 1, 'min_child_samples': 33, 'learning_rate': 0.015310236151662196, 'max_depth': 40, 'min_split_gain': 0.0036289601953245765, 'subsample': 0.5285922343912431}. Best is trial 26 with value: 0.15450790537980455.
# [I 2024-07-25 23:21:54,203] Trial 28 finished with value: 0.1490982533002499 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.043476721286515106, 'lambda_l2': 0.014279432082392405, 'num_leaves': 88, 'feature_fraction': 0.8271797044487933, 'bagging_fraction': 0.48611724585624705, 'bagging_freq': 2, 'min_child_samples': 43, 'learning_rate': 0.03521734138533799, 'max_depth': 46, 'min_split_gain': 0.11619609226448457, 'subsample': 0.6214278854267447}. Best is trial 26 with value: 0.15450790537980455.
# [I 2024-07-25 23:22:42,825] Trial 29 finished with value: 0.14880187067228018 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.38341631233891543, 'lambda_l2': 2.053629413238903, 'num_leaves': 30, 'feature_fraction': 0.7250350971608123, 'bagging_fraction': 0.43792513282167567, 'bagging_freq': 1, 'min_child_samples': 47, 'learning_rate': 0.04931333409469042, 'max_depth': 36, 'min_split_gain': 0.32923242653697027, 'subsample': 0.7107673231669995}. Best is trial 26 with value: 0.15450790537980455.
# [I 2024-07-25 23:23:02,224] Trial 30 finished with value: 0.13230516899633277 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.2802644796156315, 'lambda_l2': 0.001702405155657562, 'num_leaves': 2, 'feature_fraction': 0.9070755188791434, 'bagging_fraction': 0.9944207290938089, 'bagging_freq': 1, 'min_child_samples': 5, 'learning_rate': 0.016993712842682262, 'max_depth': 39, 'min_split_gain': 0.26694257492866924, 'subsample': 0.4938880711319512}. Best is trial 26 with value: 0.15450790537980455.
# [I 2024-07-25 23:23:35,649] Trial 31 finished with value: 0.15572757683400168 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0013293292812033913, 'lambda_l2': 0.42432098975534077, 'num_leaves': 111, 'feature_fraction': 0.800055702105446, 'bagging_fraction': 0.5254310928784343, 'bagging_freq': 1, 'min_child_samples': 30, 'learning_rate': 0.028187784656975357, 'max_depth': 46, 'min_split_gain': 0.19893686549638304, 'subsample': 0.6119613769049002}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:24:18,569] Trial 32 finished with value: 0.1517102612512598 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.002122448810771617, 'lambda_l2': 0.11957137652859631, 'num_leaves': 125, 'feature_fraction': 0.7951433682911997, 'bagging_fraction': 0.5640034959548881, 'bagging_freq': 2, 'min_child_samples': 32, 'learning_rate': 0.02793848496442008, 'max_depth': 46, 'min_split_gain': 0.3759158321452334, 'subsample': 0.6230648439877999}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:24:48,378] Trial 33 finished with value: 0.15309792520055662 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.01595155844978964, 'lambda_l2': 1.9467859867763089, 'num_leaves': 74, 'feature_fraction': 0.8877009696001272, 'bagging_fraction': 0.6646904232191375, 'bagging_freq': 1, 'min_child_samples': 29, 'learning_rate': 0.018316098641606368, 'max_depth': 46, 'min_split_gain': 0.11458039981508616, 'subsample': 0.7034919096890581}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:25:36,317] Trial 34 finished with value: 0.15055487775164117 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.00026042034495819014, 'lambda_l2': 1.0471922056682739, 'num_leaves': 102, 'feature_fraction': 0.7717575481688583, 'bagging_fraction': 0.463284315553939, 'bagging_freq': 1, 'min_child_samples': 37, 'learning_rate': 0.04670526658535544, 'max_depth': 37, 'min_split_gain': 0.19588730794962683, 'subsample': 0.5368338879561968}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:26:21,846] Trial 35 finished with value: 0.1475406106500714 and parameters: {'boosting_type': 'dart', 'lambda_l1': 9.292283323142994, 'lambda_l2': 0.025884441450729174, 'num_leaves': 68, 'feature_fraction': 0.7191344048594377, 'bagging_fraction': 0.40384272962506956, 'bagging_freq': 2, 'min_child_samples': 59, 'learning_rate': 0.032906121113462306, 'max_depth': 32, 'min_split_gain': 0.06256432956498062, 'subsample': 0.6294740482458702}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:26:54,672] Trial 36 finished with value: 0.1526780846100632 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.009845198988365535, 'lambda_l2': 0.5371372394021205, 'num_leaves': 129, 'feature_fraction': 0.8195014162143271, 'bagging_fraction': 0.5193532823561923, 'bagging_freq': 1, 'min_child_samples': 46, 'learning_rate': 0.02022237609402867, 'max_depth': 28, 'min_split_gain': 0.4006013903845759, 'subsample': 0.6765760300910924}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:27:21,445] Trial 37 finished with value: 0.15021567291146085 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0027678886691328195, 'lambda_l2': 2.2091470531796893, 'num_leaves': 47, 'feature_fraction': 0.5117790752889015, 'bagging_fraction': 0.563608983967525, 'bagging_freq': 1, 'min_child_samples': 55, 'learning_rate': 0.010443510606488302, 'max_depth': 48, 'min_split_gain': 0.2528655941405145, 'subsample': 0.4758257923122199}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:28:01,938] Trial 38 finished with value: 0.15229964888034137 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.22302578586756314, 'lambda_l2': 0.13741514980879266, 'num_leaves': 142, 'feature_fraction': 0.6436343294239388, 'bagging_fraction': 0.483353059559099, 'bagging_freq': 2, 'min_child_samples': 26, 'learning_rate': 0.04349348835484987, 'max_depth': 42, 'min_split_gain': 0.15709898896169533, 'subsample': 0.5562971263527937}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:29:06,405] Trial 39 finished with value: 0.0028626941634294543 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.0001203309898277584, 'lambda_l2': 1.7045008842896434e-05, 'num_leaves': 100, 'feature_fraction': 0.8902525703440486, 'bagging_fraction': 0.7318099065486966, 'bagging_freq': 1, 'min_child_samples': 15, 'learning_rate': 0.059318475390999374, 'max_depth': 50, 'min_split_gain': 0.5937014494264781, 'subsample': 0.7347138886646069}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:29:37,995] Trial 40 finished with value: 0.1436325169884591 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.9025225869485658, 'lambda_l2': 0.0036121356515068296, 'num_leaves': 46, 'feature_fraction': 0.9591040002814154, 'bagging_fraction': 0.44562338413182623, 'bagging_freq': 3, 'min_child_samples': 36, 'learning_rate': 0.03103198167149544, 'max_depth': 33, 'min_split_gain': 0.06112369539710116, 'subsample': 0.6649047985249255}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:30:11,055] Trial 41 finished with value: 0.1518177268022282 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0008326851567725038, 'lambda_l2': 0.4200843962722358, 'num_leaves': 115, 'feature_fraction': 0.677390624536119, 'bagging_fraction': 0.5128522216836171, 'bagging_freq': 1, 'min_child_samples': 42, 'learning_rate': 0.026403796723548017, 'max_depth': 43, 'min_split_gain': 0.1735324925061219, 'subsample': 0.5932443888306377}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:30:57,133] Trial 42 finished with value: 0.15410077414585718 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0005578967243261594, 'lambda_l2': 3.7501399630242673, 'num_leaves': 124, 'feature_fraction': 0.6998817475857322, 'bagging_fraction': 0.47898494011755627, 'bagging_freq': 1, 'min_child_samples': 30, 'learning_rate': 0.021723499584057303, 'max_depth': 39, 'min_split_gain': 0.2887791353316073, 'subsample': 0.6042729224674704}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:31:34,889] Trial 43 finished with value: 0.15152421463350307 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0018298697349961655, 'lambda_l2': 3.682686210621777, 'num_leaves': 155, 'feature_fraction': 0.7053977942466967, 'bagging_fraction': 0.4731586901177028, 'bagging_freq': 2, 'min_child_samples': 20, 'learning_rate': 0.021753699387334596, 'max_depth': 39, 'min_split_gain': 0.4905624618391372, 'subsample': 0.6499379689206832}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:32:09,290] Trial 44 finished with value: 0.15050302636255328 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.005381902488075282, 'lambda_l2': 0.7870633021685918, 'num_leaves': 126, 'feature_fraction': 0.7487472595469798, 'bagging_fraction': 0.5275572566942537, 'bagging_freq': 1, 'min_child_samples': 23, 'learning_rate': 0.014085659361639405, 'max_depth': 35, 'min_split_gain': 0.3254374404995098, 'subsample': 0.5218806409002718}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:32:48,567] Trial 45 finished with value: 0.15532034991483593 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.01464588436099079, 'lambda_l2': 3.9978563430082166, 'num_leaves': 78, 'feature_fraction': 0.6346371609866079, 'bagging_fraction': 0.5675565193293123, 'bagging_freq': 2, 'min_child_samples': 30, 'learning_rate': 0.041248178734434614, 'max_depth': 45, 'min_split_gain': 0.2917818072911561, 'subsample': 0.6076621308552255}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:33:23,809] Trial 46 finished with value: 0.153689550701729 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.043726896368949005, 'lambda_l2': 2.4756949032987148, 'num_leaves': 75, 'feature_fraction': 0.5689279504904392, 'bagging_fraction': 0.5659781518835649, 'bagging_freq': 3, 'min_child_samples': 31, 'learning_rate': 0.04132711025264372, 'max_depth': 48, 'min_split_gain': 0.43594366212027097, 'subsample': 0.6836504691853306}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:34:24,250] Trial 47 finished with value: 0.15207455796939653 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.13351340770790193, 'lambda_l2': 0.14316724128524758, 'num_leaves': 92, 'feature_fraction': 0.6328679404982658, 'bagging_fraction': 0.6381916827304663, 'bagging_freq': 2, 'min_child_samples': 26, 'learning_rate': 0.023096865962288052, 'max_depth': 38, 'min_split_gain': 0.2918753944763355, 'subsample': 0.615069764631449}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:35:01,829] Trial 48 finished with value: 0.022143979909492604 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.011998730596063295, 'lambda_l2': 0.0003823102768517935, 'num_leaves': 62, 'feature_fraction': 0.6232100579275639, 'bagging_fraction': 0.6228990799878287, 'bagging_freq': 2, 'min_child_samples': 13, 'learning_rate': 0.05773287742015877, 'max_depth': 45, 'min_split_gain': 0.5698954325464469, 'subsample': 0.6480132116552046}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:35:42,633] Trial 49 finished with value: 0.14652752607476519 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.027187993944635704, 'lambda_l2': 1.5106494869042766e-08, 'num_leaves': 102, 'feature_fraction': 0.5836185348179046, 'bagging_fraction': 0.8377423182198289, 'bagging_freq': 3, 'min_child_samples': 35, 'learning_rate': 0.029909663200426238, 'max_depth': 31, 'min_split_gain': 0.6347069329570821, 'subsample': 0.7614742911789031}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:36:21,796] Trial 50 finished with value: 0.14153793741278245 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0038165383664768176, 'lambda_l2': 5.525335222100893e-07, 'num_leaves': 81, 'feature_fraction': 0.525882412726103, 'bagging_fraction': 0.5805454062825317, 'bagging_freq': 2, 'min_child_samples': 17, 'learning_rate': 0.018981985484871438, 'max_depth': 24, 'min_split_gain': 0.35068756695384706, 'subsample': 0.46184739426415083}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:37:04,747] Trial 51 finished with value: 0.1537555433032304 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0014283621943588702, 'lambda_l2': 8.65819049347744, 'num_leaves': 131, 'feature_fraction': 0.7308326964200067, 'bagging_fraction': 0.4492436853502553, 'bagging_freq': 1, 'min_child_samples': 38, 'learning_rate': 0.03915940819122813, 'max_depth': 40, 'min_split_gain': 0.22658220869691012, 'subsample': 0.4060272776262678}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:37:37,139] Trial 52 finished with value: 0.1529211775743212 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0002962185853614536, 'lambda_l2': 3.6467140203262876, 'num_leaves': 119, 'feature_fraction': 0.7634662069701289, 'bagging_fraction': 0.5336717531194695, 'bagging_freq': 1, 'min_child_samples': 49, 'learning_rate': 0.049979741339423844, 'max_depth': 41, 'min_split_gain': 0.29438730975535315, 'subsample': 0.598540504580869}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:38:23,778] Trial 53 finished with value: 0.15481270746599635 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 9.24295509165361e-05, 'lambda_l2': 4.095461071458739, 'num_leaves': 104, 'feature_fraction': 0.6939459889371891, 'bagging_fraction': 0.48387841963485834, 'bagging_freq': 1, 'min_child_samples': 29, 'learning_rate': 0.0340782661842753, 'max_depth': 44, 'min_split_gain': 0.2211069429694953, 'subsample': 0.5522089102447476}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:39:02,719] Trial 54 finished with value: 0.15238908917553914 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 8.041617011179073e-05, 'lambda_l2': 0.900360124176071, 'num_leaves': 93, 'feature_fraction': 0.6832941845486086, 'bagging_fraction': 0.42213705746385616, 'bagging_freq': 2, 'min_child_samples': 28, 'learning_rate': 0.022650446702853533, 'max_depth': 34, 'min_split_gain': 0.12164007591549142, 'subsample': 0.5647171370173042}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:39:40,522] Trial 55 finished with value: 0.14687157692752337 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.00017834400244736228, 'lambda_l2': 0.2559240095795159, 'num_leaves': 104, 'feature_fraction': 0.6973754145982344, 'bagging_fraction': 0.47384357461474624, 'bagging_freq': 4, 'min_child_samples': 23, 'learning_rate': 0.0714441444560153, 'max_depth': 44, 'min_split_gain': 0.08759822575418597, 'subsample': 0.5003376922599021}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:40:15,806] Trial 56 finished with value: 0.1525543635851629 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.6897520385973778e-05, 'lambda_l2': 4.651484038659854, 'num_leaves': 150, 'feature_fraction': 0.5529801196215124, 'bagging_fraction': 0.6089410460901841, 'bagging_freq': 6, 'min_child_samples': 30, 'learning_rate': 0.030739266017904835, 'max_depth': 48, 'min_split_gain': 0.5262370953499933, 'subsample': 0.734886185896179}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:40:47,386] Trial 57 finished with value: 0.15167633117265925 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 3.921319314311073e-05, 'lambda_l2': 0.06551769620274807, 'num_leaves': 139, 'feature_fraction': 0.6568010194795485, 'bagging_fraction': 0.5819826661048366, 'bagging_freq': 1, 'min_child_samples': 45, 'learning_rate': 0.03900175196706449, 'max_depth': 50, 'min_split_gain': 0.4187239645969487, 'subsample': 0.547261219092643}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:41:27,142] Trial 58 finished with value: 0.14899049962502242 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.11522602914888118, 'lambda_l2': 1.3248422092633825, 'num_leaves': 105, 'feature_fraction': 0.7977842095282706, 'bagging_fraction': 0.490855573155216, 'bagging_freq': 2, 'min_child_samples': 54, 'learning_rate': 0.06419729539234, 'max_depth': 45, 'min_split_gain': 0.15387351283540193, 'subsample': 0.6910975407323128}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:41:55,524] Trial 59 finished with value: 0.14696282758942852 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.00818322598188183, 'lambda_l2': 0.49046093242693595, 'num_leaves': 47, 'feature_fraction': 0.6166859933205783, 'bagging_fraction': 0.5501966968675465, 'bagging_freq': 1, 'min_child_samples': 34, 'learning_rate': 0.09109511877321214, 'max_depth': 37, 'min_split_gain': 0.2129918072064622, 'subsample': 0.6439149642334899}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:43:09,919] Trial 60 finished with value: 0.12578080725668933 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.0010934052504961672, 'lambda_l2': 0.027312531702404715, 'num_leaves': 163, 'feature_fraction': 0.8534476635151206, 'bagging_fraction': 0.5219560412888788, 'bagging_freq': 3, 'min_child_samples': 9, 'learning_rate': 0.024706003041072608, 'max_depth': 29, 'min_split_gain': 0.2638170575777192, 'subsample': 0.6081522315400459}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:43:54,168] Trial 61 finished with value: 0.15521163545144884 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0004198271228784027, 'lambda_l2': 7.119206572260794, 'num_leaves': 111, 'feature_fraction': 0.7383633811036636, 'bagging_fraction': 0.4976305015099754, 'bagging_freq': 1, 'min_child_samples': 39, 'learning_rate': 0.03639820290769861, 'max_depth': 42, 'min_split_gain': 0.36104912812515405, 'subsample': 0.5771074434041723}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:44:39,678] Trial 62 finished with value: 0.15415012383803559 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 6.672074404249415e-05, 'lambda_l2': 4.530449301394202, 'num_leaves': 78, 'feature_fraction': 0.8215479886019359, 'bagging_fraction': 0.46792651081189357, 'bagging_freq': 1, 'min_child_samples': 25, 'learning_rate': 0.03349224285637769, 'max_depth': 44, 'min_split_gain': 0.36084386478304403, 'subsample': 0.5741103475780074}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:45:21,434] Trial 63 finished with value: 0.15373992421414975 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 7.186368606965444e-06, 'lambda_l2': 7.669446938175187, 'num_leaves': 83, 'feature_fraction': 0.7786236783310507, 'bagging_fraction': 0.4353577248772862, 'bagging_freq': 1, 'min_child_samples': 20, 'learning_rate': 0.03505188456302597, 'max_depth': 47, 'min_split_gain': 0.4477945499881857, 'subsample': 0.5351046340891835}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:45:58,366] Trial 64 finished with value: 0.15114537413278925 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 8.942237666407738e-05, 'lambda_l2': 1.4235701651818078, 'num_leaves': 65, 'feature_fraction': 0.8352644826427866, 'bagging_fraction': 0.46145202206718205, 'bagging_freq': 2, 'min_child_samples': 24, 'learning_rate': 0.044655104293073795, 'max_depth': 44, 'min_split_gain': 0.3823677709203744, 'subsample': 0.5718094098952055}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:46:29,061] Trial 65 finished with value: 0.15488145225277625 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.9805484893950233e-05, 'lambda_l2': 3.0473507883839286, 'num_leaves': 74, 'feature_fraction': 0.8102856530455863, 'bagging_fraction': 0.5050862156955391, 'bagging_freq': 1, 'min_child_samples': 39, 'learning_rate': 0.03601951636702549, 'max_depth': 41, 'min_split_gain': 0.3533242472490629, 'subsample': 0.717478115154147}. Best is trial 31 with value: 0.15572757683400168.
# [I 2024-07-25 23:47:00,066] Trial 66 finished with value: 0.15644198425902672 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 2.3714725367089238e-06, 'lambda_l2': 0.3342935962465335, 'num_leaves': 95, 'feature_fraction': 0.8762822033340092, 'bagging_fraction': 0.5053378628779723, 'bagging_freq': 1, 'min_child_samples': 39, 'learning_rate': 0.051721724658084334, 'max_depth': 42, 'min_split_gain': 0.3170338311186489, 'subsample': 0.7143006980547539}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:47:31,324] Trial 67 finished with value: 0.15421112558742445 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 3.1359514570958224e-06, 'lambda_l2': 0.1540048667973275, 'num_leaves': 94, 'feature_fraction': 0.868750018500606, 'bagging_fraction': 0.5090803880940773, 'bagging_freq': 1, 'min_child_samples': 50, 'learning_rate': 0.05086173088522718, 'max_depth': 41, 'min_split_gain': 0.3167318501557972, 'subsample': 0.7228018818099087}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:48:01,346] Trial 68 finished with value: 0.15406150753058695 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 2.1568883545894557e-06, 'lambda_l2': 0.639542542498551, 'num_leaves': 70, 'feature_fraction': 0.9323518589379087, 'bagging_fraction': 0.5506140443113888, 'bagging_freq': 1, 'min_child_samples': 43, 'learning_rate': 0.036909515764747984, 'max_depth': 47, 'min_split_gain': 0.24307922992541192, 'subsample': 0.7839633088293673}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:48:29,495] Trial 69 finished with value: 0.027745956366376567 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 3.134848444809192e-07, 'lambda_l2': 0.2545268688714672, 'num_leaves': 87, 'feature_fraction': 0.8002586143317744, 'bagging_fraction': 0.5343625254232728, 'bagging_freq': 1, 'min_child_samples': 39, 'learning_rate': 0.2538703617495327, 'max_depth': 42, 'min_split_gain': 0.19906420554286097, 'subsample': 0.5140838533730173}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:48:57,318] Trial 70 finished with value: 0.15390094957204067 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 2.5120882824964184e-05, 'lambda_l2': 9.589133591238149, 'num_leaves': 56, 'feature_fraction': 0.8716631267174776, 'bagging_fraction': 0.5884917417714816, 'bagging_freq': 1, 'min_child_samples': 33, 'learning_rate': 0.028993382865088936, 'max_depth': 36, 'min_split_gain': 0.3493146579639662, 'subsample': 0.6346845805259244}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:49:37,599] Trial 71 finished with value: 0.15361200549216303 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 8.874513581997447e-07, 'lambda_l2': 1.8704415293879522, 'num_leaves': 109, 'feature_fraction': 0.8105336265190326, 'bagging_fraction': 0.50520211547156, 'bagging_freq': 2, 'min_child_samples': 37, 'learning_rate': 0.04172880812108447, 'max_depth': 40, 'min_split_gain': 0.4029945364857561, 'subsample': 0.7596791751584984}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:50:22,935] Trial 72 finished with value: 0.1535104791036676 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.3492293509105237e-06, 'lambda_l2': 2.6213419927033956, 'num_leaves': 134, 'feature_fraction': 0.7442872078498664, 'bagging_fraction': 0.48940738960774566, 'bagging_freq': 1, 'min_child_samples': 44, 'learning_rate': 0.056973030559180605, 'max_depth': 44, 'min_split_gain': 0.4614798264821968, 'subsample': 0.7108415487534551}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:51:00,126] Trial 73 finished with value: 0.14841013480913548 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 9.38174844907679e-06, 'lambda_l2': 0.09373050035990828, 'num_leaves': 98, 'feature_fraction': 0.8378746912971619, 'bagging_fraction': 0.5679920299400907, 'bagging_freq': 4, 'min_child_samples': 47, 'learning_rate': 0.0466007126462639, 'max_depth': 49, 'min_split_gain': 0.2721966820111427, 'subsample': 0.7594083059656137}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:51:41,185] Trial 74 finished with value: 0.1534081149113918 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.000240943892451418, 'lambda_l2': 0.3662943436677065, 'num_leaves': 111, 'feature_fraction': 0.7638070214667374, 'bagging_fraction': 0.423841265477122, 'bagging_freq': 1, 'min_child_samples': 41, 'learning_rate': 0.06197934820099147, 'max_depth': 46, 'min_split_gain': 0.5122164321938145, 'subsample': 0.8120827148597093}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:52:22,286] Trial 75 finished with value: 0.15253512575557543 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 2.2082647677367118e-05, 'lambda_l2': 1.0151045434098327, 'num_leaves': 87, 'feature_fraction': 0.6566439660224909, 'bagging_fraction': 0.5220977002465967, 'bagging_freq': 2, 'min_child_samples': 39, 'learning_rate': 0.05203246658587201, 'max_depth': 38, 'min_split_gain': 0.1515864502348488, 'subsample': 0.6677497579020061}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:53:18,526] Trial 76 finished with value: 0.15137433051971544 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.5300533424599564, 'lambda_l2': 0.7358406916996912, 'num_leaves': 53, 'feature_fraction': 0.916979908302878, 'bagging_fraction': 0.4965987203902981, 'bagging_freq': 1, 'min_child_samples': 34, 'learning_rate': 0.07576530426451072, 'max_depth': 43, 'min_split_gain': 0.3327950972338136, 'subsample': 0.6903213387001952}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:53:54,286] Trial 77 finished with value: 0.15146130357632936 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 3.477917250237975e-08, 'lambda_l2': 0.00616347754518927, 'num_leaves': 120, 'feature_fraction': 0.9772737610143533, 'bagging_fraction': 0.5484433679685352, 'bagging_freq': 1, 'min_child_samples': 28, 'learning_rate': 0.026256726518145486, 'max_depth': 41, 'min_split_gain': 0.3170375788731902, 'subsample': 0.6688420777572266}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:54:37,376] Trial 78 finished with value: 0.14814695960094046 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 4.815461778338896e-05, 'lambda_l2': 0.015012427540070625, 'num_leaves': 107, 'feature_fraction': 0.7366561841409347, 'bagging_fraction': 0.45780814265237096, 'bagging_freq': 2, 'min_child_samples': 32, 'learning_rate': 0.032631306175798576, 'max_depth': 19, 'min_split_gain': 0.23582304592467662, 'subsample': 0.7441346915844488}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:55:13,933] Trial 79 finished with value: 0.15369574489174023 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.00037575702225694753, 'lambda_l2': 4.318843515418923, 'num_leaves': 29, 'feature_fraction': 0.587527340458489, 'bagging_fraction': 0.40139033169458976, 'bagging_freq': 1, 'min_child_samples': 57, 'learning_rate': 0.03653360665141319, 'max_depth': 45, 'min_split_gain': 0.17826948060073367, 'subsample': 0.7157777801513758}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:55:52,486] Trial 80 finished with value: 0.1525181826741734 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0001622211145755389, 'lambda_l2': 0.04593313304963717, 'num_leaves': 72, 'feature_fraction': 0.7844577171574317, 'bagging_fraction': 0.6132409113259938, 'bagging_freq': 2, 'min_child_samples': 51, 'learning_rate': 0.04267436195053629, 'max_depth': 38, 'min_split_gain': 0.4642263056183931, 'subsample': 0.5527222320641755}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:56:23,827] Trial 81 finished with value: 0.15030307173317464 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 2.301819690835182e-06, 'lambda_l2': 0.14716709665750405, 'num_leaves': 96, 'feature_fraction': 0.8640141182696799, 'bagging_fraction': 0.5080571974534271, 'bagging_freq': 1, 'min_child_samples': 63, 'learning_rate': 0.05531404539204532, 'max_depth': 41, 'min_split_gain': 0.31361774492274036, 'subsample': 0.7187921738017211}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:56:55,731] Trial 82 finished with value: 0.15130761143495403 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 5.904900780672135e-06, 'lambda_l2': 0.18730419522226696, 'num_leaves': 88, 'feature_fraction': 0.8908825876607989, 'bagging_fraction': 0.5176093553190845, 'bagging_freq': 1, 'min_child_samples': 48, 'learning_rate': 0.05133262191776445, 'max_depth': 42, 'min_split_gain': 0.28257256658260166, 'subsample': 0.779928849903656}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:57:30,648] Trial 83 finished with value: 0.15545091353853238 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 3.568918069932742e-06, 'lambda_l2': 0.38567617915907665, 'num_leaves': 98, 'feature_fraction': 0.8654196982835389, 'bagging_fraction': 0.535477547454493, 'bagging_freq': 7, 'min_child_samples': 45, 'learning_rate': 0.04729706615551968, 'max_depth': 40, 'min_split_gain': 0.37517052750017654, 'subsample': 0.7372308915211869}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:58:10,428] Trial 84 finished with value: 0.15421356791567112 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.622267749386486e-05, 'lambda_l2': 1.735915018652064, 'num_leaves': 121, 'feature_fraction': 0.815492281680816, 'bagging_fraction': 0.6470026320070832, 'bagging_freq': 7, 'min_child_samples': 38, 'learning_rate': 0.04613656438528429, 'max_depth': 43, 'min_split_gain': 0.3612895668451313, 'subsample': 0.701101861570636}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:58:48,594] Trial 85 finished with value: 0.15605007133512502 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0006884592492948637, 'lambda_l2': 0.38135719893536796, 'num_leaves': 113, 'feature_fraction': 0.8368696485845272, 'bagging_fraction': 0.5362636591529711, 'bagging_freq': 5, 'min_child_samples': 35, 'learning_rate': 0.02449146611638987, 'max_depth': 35, 'min_split_gain': 0.38999497445525283, 'subsample': 0.8054855972845248}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:59:22,857] Trial 86 finished with value: 0.15622020310946122 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.004202259157115764, 'lambda_l2': 0.35195667401056824, 'num_leaves': 79, 'feature_fraction': 0.8425562074115588, 'bagging_fraction': 0.5381241413601906, 'bagging_freq': 6, 'min_child_samples': 36, 'learning_rate': 0.02953710655612703, 'max_depth': 35, 'min_split_gain': 0.41742066958709445, 'subsample': 0.8396460846589291}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-25 23:59:58,143] Trial 87 finished with value: 0.1524149107168277 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0036054225047543833, 'lambda_l2': 0.3332175961096554, 'num_leaves': 80, 'feature_fraction': 0.9047506701489249, 'bagging_fraction': 0.5707740807832047, 'bagging_freq': 6, 'min_child_samples': 36, 'learning_rate': 0.028090734606529614, 'max_depth': 35, 'min_split_gain': 0.4189662605206719, 'subsample': 0.8912562654370828}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:00:33,952] Trial 88 finished with value: 0.1533615836131836 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.01975765210285552, 'lambda_l2': 2.66659705293014, 'num_leaves': 99, 'feature_fraction': 0.8392353443808893, 'bagging_fraction': 0.5398392436796501, 'bagging_freq': 5, 'min_child_samples': 31, 'learning_rate': 0.032805691314684846, 'max_depth': 36, 'min_split_gain': 0.4139243723517889, 'subsample': 0.8313027117371161}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:01:39,778] Trial 89 finished with value: 0.1438935748367172 and parameters: {'boosting_type': 'dart', 'lambda_l1': 0.0010364461387680597, 'lambda_l2': 0.09214539045523563, 'num_leaves': 114, 'feature_fraction': 0.8791463984390655, 'bagging_fraction': 0.5568373884846897, 'bagging_freq': 6, 'min_child_samples': 28, 'learning_rate': 0.020309631233558403, 'max_depth': 39, 'min_split_gain': 0.36538624844192474, 'subsample': 0.8606700945880785}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:02:13,908] Trial 90 finished with value: 0.13473401212953365 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.002039746900750633, 'lambda_l2': 9.87060536870835e-06, 'num_leaves': 65, 'feature_fraction': 0.8542588744288907, 'bagging_fraction': 0.767388280390709, 'bagging_freq': 7, 'min_child_samples': 45, 'learning_rate': 0.038070825520558176, 'max_depth': 34, 'min_split_gain': 0.38312466018868657, 'subsample': 0.8099483083956838}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:02:51,097] Trial 91 finished with value: 0.1534561108233625 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.006021791623184177, 'lambda_l2': 0.5588356771307995, 'num_leaves': 91, 'feature_fraction': 0.8042371434110511, 'bagging_fraction': 0.5350534928999441, 'bagging_freq': 5, 'min_child_samples': 41, 'learning_rate': 0.025273096736626977, 'max_depth': 40, 'min_split_gain': 0.25728437099765633, 'subsample': 0.846378744495285}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:03:25,934] Trial 92 finished with value: 0.15148208554781867 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.07953616148737058, 'lambda_l2': 6.329233889569353, 'num_leaves': 74, 'feature_fraction': 0.844160861054147, 'bagging_fraction': 0.6806259666357023, 'bagging_freq': 7, 'min_child_samples': 35, 'learning_rate': 0.023425024865431274, 'max_depth': 47, 'min_split_gain': 0.3021089262276376, 'subsample': 0.8972349538150509}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:03:59,567] Trial 93 finished with value: 0.15207027975936138 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.004512835387910335, 'lambda_l2': 1.0712153273194716, 'num_leaves': 84, 'feature_fraction': 0.8236782786124006, 'bagging_fraction': 0.4780310327939198, 'bagging_freq': 6, 'min_child_samples': 43, 'learning_rate': 0.031063733874257832, 'max_depth': 32, 'min_split_gain': 0.34057207180319227, 'subsample': 0.5808300630401775}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:04:37,331] Trial 94 finished with value: 0.15189923093908847 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.0005709484603025053, 'lambda_l2': 2.981680977750866, 'num_leaves': 109, 'feature_fraction': 0.7624674350779204, 'bagging_fraction': 0.5971996559472169, 'bagging_freq': 6, 'min_child_samples': 33, 'learning_rate': 0.02803584448082684, 'max_depth': 45, 'min_split_gain': 0.20455026594229236, 'subsample': 0.9356558775714021}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:05:14,723] Trial 95 finished with value: 0.14887491923650228 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.02774435427805102, 'lambda_l2': 0.29523408385598104, 'num_leaves': 103, 'feature_fraction': 0.8597535042718374, 'bagging_fraction': 0.5767323918093585, 'bagging_freq': 7, 'min_child_samples': 40, 'learning_rate': 0.016522880337136944, 'max_depth': 27, 'min_split_gain': 0.3858421791263696, 'subsample': 0.5951973681336576}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:05:46,217] Trial 96 finished with value: 0.15059547591934525 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 1.6216800560320582e-07, 'lambda_l2': 1.3903202827527423, 'num_leaves': 60, 'feature_fraction': 0.713884076312962, 'bagging_fraction': 0.5279163075571454, 'bagging_freq': 5, 'min_child_samples': 37, 'learning_rate': 0.040074887512822524, 'max_depth': 37, 'min_split_gain': 0.4331388264688977, 'subsample': 0.6149559611297771}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:06:22,697] Trial 97 finished with value: 0.13400542819926853 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.00011095305663332931, 'lambda_l2': 8.715649473069783e-05, 'num_leaves': 78, 'feature_fraction': 0.8302214168057944, 'bagging_fraction': 0.4936510286737587, 'bagging_freq': 6, 'min_child_samples': 31, 'learning_rate': 0.03565915143161836, 'max_depth': 43, 'min_split_gain': 0.140222707363312, 'subsample': 0.6354334483919606}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:06:58,919] Trial 98 finished with value: 0.15268613635597927 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 0.001759729134130013, 'lambda_l2': 5.975387609203359, 'num_leaves': 97, 'feature_fraction': 0.9015296479090605, 'bagging_fraction': 0.5563934871606805, 'bagging_freq': 4, 'min_child_samples': 26, 'learning_rate': 0.02489262466405125, 'max_depth': 41, 'min_split_gain': 0.2191647775244121, 'subsample': 0.7718606889434787}. Best is trial 66 with value: 0.15644198425902672.
# [I 2024-07-26 00:07:37,188] Trial 99 finished with value: 0.1539281867984904 and parameters: {'boosting_type': 'gbdt', 'lambda_l1': 3.476980921658865e-05, 'lambda_l2': 0.5582224331912258, 'num_leaves': 126, 'feature_fraction': 0.7841277108851776, 'bagging_fraction': 0.5158502065670119, 'bagging_freq': 5, 'min_child_samples': 29, 'learning_rate': 0.020546437201416166, 'max_depth': 49, 'min_split_gain': 0.471358383224287, 'subsample': 0.6561924598189947}. Best is trial 66 with value: 0.15644198425902672.
# Number of finished trials: 100
# Best trial:
#   Value: 0.15644198425902672
#   Params:
#     boosting_type: gbdt
#     lambda_l1: 2.3714725367089238e-06
#     lambda_l2: 0.3342935962465335
#     num_leaves: 95
#     feature_fraction: 0.8762822033340092
#     bagging_fraction: 0.5053378628779723
#     bagging_freq: 1
#     min_child_samples: 39
#     learning_rate: 0.051721724658084334
#     max_depth: 42
#     min_split_gain: 0.3170338311186489
#     subsample: 0.7143006980547539

# %%
trial.params
# Out:
# {'boosting_type': 'gbdt',
#  'lambda_l1': 2.3714725367089238e-06,
#  'lambda_l2': 0.3342935962465335,
#  'num_leaves': 95,
#  'feature_fraction': 0.8762822033340092,
#  'bagging_fraction': 0.5053378628779723,
#  'bagging_freq': 1,
#  'min_child_samples': 39,
#  'learning_rate': 0.051721724658084334,
#  'max_depth': 42,
#  'min_split_gain': 0.3170338311186489,
#  'subsample': 0.7143006980547539}

# %%
new_params = {'boosting_type': 'gbdt',
 'lambda_l1': 2.3714725367089238e-06,
 'lambda_l2': 0.3342935962465335,
 'num_leaves': 95,
 'feature_fraction': 0.8762822033340092,
 'bagging_fraction': 0.5053378628779723,
 'bagging_freq': 1,
 'min_child_samples': 39,
 'learning_rate': 0.051721724658084334,
 'max_depth': 42,
 'min_split_gain': 0.3170338311186489,
 'subsample': 0.7143006980547539}
lgb_scores = []
lgb_models = []
for fold in tqdm(range(N_SPLITS)):
    _df_train = df_train[df_train["fold"] != fold].reset_index(drop=True)
    _df_valid = df_train[df_train["fold"] == fold].reset_index(drop=True)
    # model = lgb.LGBMClassifier(**new_params)
    model = VotingClassifier([(f"lgb_{i}", lgb.LGBMClassifier(random_state=i, **new_params)) for i in range(3)], voting="soft")
    model.fit(_df_train[train_cols], _df_train["target"])
    preds = model.predict_proba(_df_valid[train_cols])[:, 1]
    score = comp_score(_df_valid[["target"]], pd.DataFrame(preds, columns=["prediction"]), "")
    print(f"fold: {fold} - Partial AUC Score: {score:.5f}")
    lgb_scores.append(score)
    lgb_models.append(model)

# %%
lgbm_score = np.mean(lgb_scores)
print(f"LGBM Score: {lgbm_score:.5f}")

# %% [markdown]
# # LGBM Feature Importances

# %%
importances = np.mean([estimator.feature_importances_ for model in lgb_models for estimator in model.estimators_ ], 0)
df_imp = pd.DataFrame({"feature": lgb_models[0].estimators_[0].feature_name_, "importance": importances}).sort_values("importance").reset_index(drop=True)
df_imp.to_csv("imp_lgbm.csv", index=False)

plt.figure(figsize=(16, 12))
plt.barh(df_imp["feature"], df_imp["importance"])
plt.show()

# %% [markdown]
# # Catboost Model

# %%
def objective(trial):
    param = {
        "objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-5, 100, log=True),
        "border_count": trial.suggest_int("border_count", 32, 255),
        "task_type": "GPU",
        "grow_policy": trial.suggest_categorical("grow_policy", ["SymmetricTree", "Depthwise", "Lossguide"]),
        # "used_ram_limit": "3gb",
    }
    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)

    scores = []
    for fold in range(N_SPLITS):
        _df_train = df_train[df_train["fold"] != fold].reset_index(drop=True)
        _df_valid = df_train[df_train["fold"] == fold].reset_index(drop=True)
        gbm = cb.CatBoostClassifier(**param)
        gbm.fit(_df_train[train_cols], _df_train["target"], eval_set=[(_df_valid[train_cols], _df_valid["target"])], verbose=0, early_stopping_rounds=100)
        preds = gbm.predict(_df_valid[train_cols])
        score = comp_score(_df_valid[["target"]], pd.DataFrame(preds, columns=["prediction"]), "")
        scores.append(score)
    return np.mean(scores)

# %%
import optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# %%
cb_params = {
    'objective': 'Logloss',
    # "random_state": 42,
    "colsample_bylevel": 0.3, # 0.01, 0.1
    "iterations": 400,
    "learning_rate": 0.05,
    "cat_features": cat_cols,
    "max_depth": 8,
    "l2_leaf_reg": 5,
    # "task_type": "GPU",
    # "scale_pos_weight": 2,
    "verbose": 0,
}
cb_scores = []
cb_models = []
for fold in tqdm(range(N_SPLITS)):
    _df_train = df_train[df_train["fold"] != fold].reset_index(drop=True)
    _df_valid = df_train[df_train["fold"] == fold].reset_index(drop=True)
    model = cb.CatBoostClassifier(**cb_params)
    model = VotingClassifier([(f"cb_{i}", cb.CatBoostClassifier(random_state=i, **cb_params)) for i in range(3)], voting="soft")
    # eval_set=(_df_valid[train_cols], _df_valid["target"]), early_stopping_rounds=50
    model.fit(_df_train[train_cols], _df_train["target"])
    preds = model.predict_proba(_df_valid[train_cols])[:, 1]
    score = comp_score(_df_valid[["target"]], pd.DataFrame(preds, columns=["prediction"]), "")
    print(f"fold: {fold} - Partial AUC Score: {score:.5f}")
    cb_scores.append(score)
    cb_models.append(model)

# %%
cb_score = np.mean(cb_scores)
print(f"CatBoost Score: {cb_score:.5f}")

# %% [markdown]
# # CatBoost Feature Importances

# %%
importances = np.mean([estimator.feature_importances_ for model in cb_models for estimator in model.estimators_ ], 0)
df_imp = pd.DataFrame({"feature": cb_models[0].estimators_[0].feature_names_, "importance": importances}).sort_values("importance").reset_index(drop=True)
df_imp.to_csv("imp_catb.csv", index=False)

plt.figure(figsize=(16, 12))
plt.barh(df_imp["feature"], df_imp["importance"])
plt.show()

# %% [markdown]
# # Ensembling

# %%
X_cat = category_encoder.transform(df_test[cat_cols])
for c, cat_col in enumerate(cat_cols):
    df_test[cat_col] = X_cat[:, c]

# %%
# inference
lgb_preds = np.mean([model.predict_proba(df_test[train_cols])[:, 1] for model in lgb_models], 0)
cb_preds = np.mean([model.predict_proba(df_test[train_cols])[:, 1] for model in cb_models], 0)
preds = lgb_preds * 0.5 + cb_preds * 0.5

# %%
df_sub = pd.read_csv("/kaggle/input/isic-2024-challenge/sample_submission.csv")
df_sub["target"] = preds
df_sub

# %%
df_sub.to_csv("submission.csv", index=False)
